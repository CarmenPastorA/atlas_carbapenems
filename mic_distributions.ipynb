# %% [markdown]
# # PLOT MIC DISTRIBUTIONS
# FOR ANY PATHOGEN-ANTIBIOTIC PAIRS

# %%
from functions import *
sp='Streptococcus pneumoniae'
dr='Meropenem'
#CORRELELOGRAM
R,Y=read_corr(sp,dr)
fig=plt.figure()
ax=plt.gca()
title=sp+'\n'+dr    
I=plot_corr(R,Y,ax,fig,title)
#fig.savefig("figures/8.mic_dist_corr/Corr_"+sp+"_"+dr+".pdf", format='pdf', dpi=1000)
#WATERFALL PLOT
title=''
Z, pY=read_micdist(sp,dr)
fig=plt.figure()
ax=plot_waterfall(Z,pY,fig,title)
#fig.savefig("figures/8.mic_dist_corr/Waterfall_"+sp+"_"+dr+".pdf", format='pdf', dpi=1000)
#ax.view_init(30, 290)
#HEATMAP
fig=plt.figure()
ax=plt.gca()
H=plot_micdist(Z,pY,fig,ax,title)
#fig.savefig("figures/8.mic_dist_corr/Heatmap_"+sp+"_"+dr+".pdf", format='pdf', dpi=1000)
